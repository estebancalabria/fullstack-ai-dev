# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
# !pip uninstall torch torchaudio torchvision -y
# !pip install torch torchaudio torchvision
# Out:
# Found existing installation: torch 2.3.1
# Uninstalling torch-2.3.1:
#   Successfully uninstalled torch-2.3.1
# Found existing installation: torchaudio 2.11.0
# Uninstalling torchaudio-2.11.0:
#   Successfully uninstalled torchaudio-2.11.0
# Found existing installation: torchvision 0.18.1
# Uninstalling torchvision-0.18.1:
#   Successfully uninstalled torchvision-0.18.1
# WARNING: Failed to remove contents in a temporary directory 'C:\Coding\Python\Lib\site-packages\~orch'.
# You can safely remove it manually.
# Collecting torch
#   Downloading torch-2.13.0-cp311-cp311-win_amd64.whl.metadata (39 kB)
# Collecting torchaudio
#   Using cached torchaudio-2.11.0-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Collecting torchvision
#   Downloading torchvision-0.28.0-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: filelock in C:\Coding\Python\Lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Coding\Python\Lib\site-packages (from torch) (4.15.0)
# Collecting setuptools>=77.0.3 (from torch)
#   Using cached setuptools-83.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in C:\Coding\Python\Lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in C:\Coding\Python\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Coding\Python\Lib\site-packages (from torch) (2024.10.0)
# Requirement already satisfied: numpy in C:\Coding\Python\Lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in C:\Coding\Python\Lib\site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Coding\Python\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Coding\Python\Lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.13.0-cp311-cp311-win_amd64.whl (122.0 MB)
#    ---------------------------------------- 0.0/122.0 MB ? eta -:--:--
#    -- ------------------------------------- 8.1/122.0 MB 41.8 MB/s eta 0:00:03
#    ------- -------------------------------- 22.0/122.0 MB 53.6 MB/s eta 0:00:02
#    ------------ --------------------------- 36.7/122.0 MB 58.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 51.6/122.0 MB 62.1 MB/s eta 0:00:02
#    --------------------- ------------------ 66.1/122.0 MB 63.8 MB/s eta 0:00:01
#    ------------------------- -------------- 79.2/122.0 MB 63.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 91.0/122.0 MB 61.7 MB/s eta 0:00:01
#    -------------------------------- ------ 103.0/122.0 MB 60.9 MB/s eta 0:00:01
#    ------------------------------------ -- 113.5/122.0 MB 59.9 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    --------------------------------------  121.9/122.0 MB 59.4 MB/s eta 0:00:01
#    ---------------------------------------- 122.0/122.0 MB 21.5 MB/s  0:00:05
# Using cached torchaudio-2.11.0-cp311-cp311-win_amd64.whl (328 kB)
# Downloading torchvision-0.28.0-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 3.8/3.8 MB 32.3 MB/s  0:00:00
# Using cached setuptools-83.0.0-py3-none-any.whl (1.0 MB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 6.3/6.3 MB 38.7 MB/s  0:00:00
# Installing collected packages: torchaudio, sympy, setuptools, torch, torchvision
#
#    ---------------------------------------- 0/5 [torchaudio]
#    ---------------------------------------- 0/5 [torchaudio]
#    ---------------------------------------- 0/5 [torchaudio]
#    ---------------------------------------- 0/5 [torchaudio]
#    ---------------------------------------- 0/5 [torchaudio]
#    ---------------------------------------- 0/5 [torchaudio]
#    ---------------------------------------- 0/5 [torchaudio]
#    ---------------------------------------- 0/5 [torchaudio]
#   Attempting uninstall: sympy
#    ---------------------------------------- 0/5 [torchaudio]
#     Found existing installation: sympy 1.12.1
#    ---------------------------------------- 0/5 [torchaudio]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#     Uninstalling sympy-1.12.1:
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#       Successfully uninstalled sympy-1.12.1
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#    -------- ------------------------------- 1/5 [sympy]
#   Attempting uninstall: setuptools
#    -------- ------------------------------- 1/5 [sympy]
#    ---------------- ----------------------- 2/5 [setuptools]
#     Found existing installation: setuptools 65.5.0
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#     Uninstalling setuptools-65.5.0:
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#       Successfully uninstalled setuptools-65.5.0
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ---------------- ----------------------- 2/5 [setuptools]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
# ...
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    ------------------------ --------------- 3/5 [torch]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    -------------------------------- ------- 4/5 [torchvision]
#    ---------------------------------------- 5/5 [torchvision]
#
# Successfully installed setuptools-83.0.0 sympy-1.14.0 torch-2.13.0 torchaudio-2.11.0 torchvision-0.28.0
# WARNING: Error parsing dependencies of torchsde: .* suffix can only be used with `==` or `!=` operators
#     numpy (>=1.19.*) ; python_version >= "3.7"
#            ~~~~~~~^
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install coqui-tts
# Out:
# WARNING: Skipping TTS as it is not installed.
# Collecting coqui-tts
#   Downloading coqui_tts-0.27.5-py3-none-any.whl.metadata (21 kB)
# Collecting anyascii>=0.3.0 (from coqui-tts)
#   Using cached anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting coqpit-config<0.3.0,>=0.2.0 (from coqui-tts)
#   Downloading coqpit_config-0.2.5-py3-none-any.whl.metadata (11 kB)
# Collecting coqui-tts-trainer<0.4.0,>=0.3.0 (from coqui-tts)
#   Downloading coqui_tts_trainer-0.3.3-py3-none-any.whl.metadata (8.4 kB)
# Collecting einops>=0.6.0 (from coqui-tts)
#   Using cached einops-0.8.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: fsspec>=2023.6.0 in C:\Coding\Python\Lib\site-packages (from fsspec[http]>=2023.6.0->coqui-tts) (2024.10.0)
# Collecting inflect>=5.6.0 (from coqui-tts)
#   Using cached inflect-7.5.0-py3-none-any.whl.metadata (24 kB)
# Collecting ko-speech-tools>=0.1.0 (from coqui-tts)
#   Downloading ko_speech_tools-0.1.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting librosa>=0.11.0 (from coqui-tts)
#   Using cached librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: matplotlib>=3.8.4 in C:\Coding\Python\Lib\site-packages (from coqui-tts) (3.10.8)
# Collecting monotonic-alignment-search>=0.1.0 (from coqui-tts)
#   Downloading monotonic_alignment_search-0.2.1-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Collecting num2words>=0.5.14 (from coqui-tts)
#   Using cached num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Collecting numba>=0.58.0 (from coqui-tts)
#   Using cached numba-0.66.0-cp311-cp311-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy>=1.26.0 in C:\Coding\Python\Lib\site-packages (from coqui-tts) (1.26.4)
# Requirement already satisfied: packaging>=23.1 in C:\Coding\Python\Lib\site-packages (from coqui-tts) (24.2)
# Collecting pysbd>=0.3.4 (from coqui-tts)
#   Using cached pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pyyaml>=6.0 in C:\Coding\Python\Lib\site-packages (from coqui-tts) (6.0.2)
# Requirement already satisfied: scipy>=1.13.0 in C:\Coding\Python\Lib\site-packages (from coqui-tts) (1.13.1)
# Requirement already satisfied: soundfile>=0.12.0 in C:\Coding\Python\Lib\site-packages (from coqui-tts) (0.12.1)
# Requirement already satisfied: tqdm>=4.64.1 in C:\Coding\Python\Lib\site-packages (from coqui-tts) (4.67.1)
# Requirement already satisfied: transformers>=4.57 in C:\Coding\Python\Lib\site-packages (from coqui-tts) (4.57.3)
# Requirement already satisfied: typing-extensions>=4.10 in C:\Coding\Python\Lib\site-packages (from coqui-tts) (4.15.0)
# Requirement already satisfied: psutil>=5 in C:\Coding\Python\Lib\site-packages (from coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (7.2.2)
# Collecting tensorboard>=2.17.1 (from coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts)
#   Using cached tensorboard-2.21.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in C:\Coding\Python\Lib\site-packages (from fsspec[http]>=2023.6.0->coqui-tts) (3.11.10)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in C:\Coding\Python\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in C:\Coding\Python\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in C:\Coding\Python\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Coding\Python\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Coding\Python\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in C:\Coding\Python\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Coding\Python\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (1.18.3)
# Requirement already satisfied: idna>=2.0 in C:\Coding\Python\Lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts) (3.10)
# Collecting more_itertools>=8.5.0 (from inflect>=5.6.0->coqui-tts)
#   Using cached more_itertools-11.1.0-py3-none-any.whl.metadata (41 kB)
# Collecting typeguard>=4.0.1 (from inflect>=5.6.0->coqui-tts)
#   Using cached typeguard-4.5.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting audioread>=2.1.9 (from librosa>=0.11.0->coqui-tts)
#   Using cached audioread-3.1.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: scikit-learn>=1.1.0 in C:\Coding\Python\Lib\site-packages (from librosa>=0.11.0->coqui-tts) (1.8.0)
# Requirement already satisfied: joblib>=1.0 in C:\Coding\Python\Lib\site-packages (from librosa>=0.11.0->coqui-tts) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in C:\Coding\Python\Lib\site-packages (from librosa>=0.11.0->coqui-tts) (4.4.2)
# Collecting pooch>=1.1 (from librosa>=0.11.0->coqui-tts)
#   Using cached pooch-1.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa>=0.11.0->coqui-tts)
#   Using cached soxr-1.1.0-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting lazy_loader>=0.1 (from librosa>=0.11.0->coqui-tts)
#   Using cached lazy_loader-0.5-py3-none-any.whl.metadata (5.9 kB)
# Collecting msgpack>=1.0 (from librosa>=0.11.0->coqui-tts)
#   Using cached msgpack-1.2.1-cp311-cp311-win_amd64.whl.metadata (8.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Coding\Python\Lib\site-packages (from matplotlib>=3.8.4->coqui-tts) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in C:\Coding\Python\Lib\site-packages (from matplotlib>=3.8.4->coqui-tts) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Coding\Python\Lib\site-packages (from matplotlib>=3.8.4->coqui-tts) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Coding\Python\Lib\site-packages (from matplotlib>=3.8.4->coqui-tts) (1.4.5)
# Requirement already satisfied: pillow>=8 in C:\Coding\Python\Lib\site-packages (from matplotlib>=3.8.4->coqui-tts) (10.4.0)
# Requirement already satisfied: pyparsing>=3 in C:\Coding\Python\Lib\site-packages (from matplotlib>=3.8.4->coqui-tts) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Coding\Python\Lib\site-packages (from matplotlib>=3.8.4->coqui-tts) (2.9.0.post0)
# Collecting docopt>=0.6.2 (from num2words>=0.5.14->coqui-tts)
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Collecting llvmlite<0.49,>=0.48.0dev0 (from numba>=0.58.0->coqui-tts)
#   Using cached llvmlite-0.48.0-cp311-cp311-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in C:\Coding\Python\Lib\site-packages (from pooch>=1.1->librosa>=0.11.0->coqui-tts) (4.10.0)
# Requirement already satisfied: requests>=2.19.0 in C:\Coding\Python\Lib\site-packages (from pooch>=1.1->librosa>=0.11.0->coqui-tts) (2.32.4)
# Requirement already satisfied: six>=1.5 in C:\Coding\Python\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.8.4->coqui-tts) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Coding\Python\Lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.11.0->coqui-tts) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Coding\Python\Lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.11.0->coqui-tts) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Coding\Python\Lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.11.0->coqui-tts) (2024.8.30)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Coding\Python\Lib\site-packages (from scikit-learn>=1.1.0->librosa>=0.11.0->coqui-tts) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in C:\Coding\Python\Lib\site-packages (from soundfile>=0.12.0->coqui-tts) (1.17.1)
# Requirement already satisfied: pycparser in C:\Coding\Python\Lib\site-packages (from cffi>=1.0->soundfile>=0.12.0->coqui-tts) (2.22)
# Collecting absl-py>=0.4 (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts)
#   Using cached absl_py-2.5.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: grpcio<2.0,>=1.74.0 in C:\Coding\Python\Lib\site-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (1.74.0)
# Collecting markdown>=2.6.8 (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts)
#   Using cached markdown-3.10.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting protobuf<8.0.0,>=6.31.1 (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts)
#   Using cached protobuf-7.35.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in C:\Coding\Python\Lib\site-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (65.5.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in C:\Coding\Python\Lib\site-packages (from tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (3.0.3)
# Requirement already satisfied: colorama in C:\Coding\Python\Lib\site-packages (from tqdm>=4.64.1->coqui-tts) (0.4.6)
# Requirement already satisfied: filelock in C:\Coding\Python\Lib\site-packages (from transformers>=4.57->coqui-tts) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in C:\Coding\Python\Lib\site-packages (from transformers>=4.57->coqui-tts) (0.36.0)
# Requirement already satisfied: regex!=2019.12.17 in C:\Coding\Python\Lib\site-packages (from transformers>=4.57->coqui-tts) (2024.11.6)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Coding\Python\Lib\site-packages (from transformers>=4.57->coqui-tts) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Coding\Python\Lib\site-packages (from transformers>=4.57->coqui-tts) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in C:\Coding\Python\Lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts) (3.0.2)
# Downloading coqui_tts-0.27.5-py3-none-any.whl (862 kB)
#    ---------------------------------------- 0.0/862.8 kB ? eta -:--:--
#    ---------------------------------------- 862.8/862.8 kB 9.7 MB/s  0:00:00
# Downloading coqpit_config-0.2.5-py3-none-any.whl (15 kB)
# Downloading coqui_tts_trainer-0.3.3-py3-none-any.whl (56 kB)
# Using cached anyascii-0.3.3-py3-none-any.whl (345 kB)
# Using cached einops-0.8.2-py3-none-any.whl (65 kB)
# Using cached inflect-7.5.0-py3-none-any.whl (35 kB)
# Downloading ko_speech_tools-0.1.0-py3-none-any.whl (997 kB)
#    ---------------------------------------- 0.0/997.3 kB ? eta -:--:--
#    ---------------------------------------- 997.3/997.3 kB 23.0 MB/s  0:00:00
# Using cached librosa-0.11.0-py3-none-any.whl (260 kB)
# Using cached audioread-3.1.0-py3-none-any.whl (23 kB)
# Using cached lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# Downloading monotonic_alignment_search-0.2.1-cp311-cp311-win_amd64.whl (228 kB)
# Using cached more_itertools-11.1.0-py3-none-any.whl (72 kB)
# Using cached msgpack-1.2.1-cp311-cp311-win_amd64.whl (70 kB)
# Using cached num2words-0.5.14-py3-none-any.whl (163 kB)
# Using cached numba-0.66.0-cp311-cp311-win_amd64.whl (2.8 MB)
# Using cached llvmlite-0.48.0-cp311-cp311-win_amd64.whl (41.9 MB)
# Using cached pooch-1.9.0-py3-none-any.whl (67 kB)
# Using cached pysbd-0.3.4-py3-none-any.whl (71 kB)
# Using cached soxr-1.1.0-cp311-cp311-win_amd64.whl (176 kB)
# Using cached tensorboard-2.21.0-py3-none-any.whl (5.5 MB)
# Using cached protobuf-7.35.1-cp310-abi3-win_amd64.whl (439 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached absl_py-2.5.0-py3-none-any.whl (137 kB)
# Using cached markdown-3.10.2-py3-none-any.whl (108 kB)
# Using cached typeguard-4.5.2-py3-none-any.whl (36 kB)
# Installing collected packages: docopt, typeguard, tensorboard-data-server, soxr, pysbd, protobuf, num2words, msgpack, more_itertools, monotonic-alignment-search, markdown, llvmlite, lazy_loader, ko-speech-tools, einops, coqpit-config, audioread, anyascii, absl-py, tensorboard, pooch, numba, inflect, librosa, coqui-tts-trainer, coqui-tts
#
#    - --------------------------------------  1/26 [typeguard]
#    - --------------------------------------  1/26 [typeguard]
#    ---- -----------------------------------  3/26 [soxr]
#    ------ ---------------------------------  4/26 [pysbd]
#    ------ ---------------------------------  4/26 [pysbd]
#    ------ ---------------------------------  4/26 [pysbd]
#    ------ ---------------------------------  4/26 [pysbd]
#    ------ ---------------------------------  4/26 [pysbd]
#    ------ ---------------------------------  4/26 [pysbd]
#    ------ ---------------------------------  4/26 [pysbd]
#   Attempting uninstall: protobuf
#    ------ ---------------------------------  4/26 [pysbd]
#     Found existing installation: protobuf 5.27.1
#    ------ ---------------------------------  4/26 [pysbd]
#     Uninstalling protobuf-5.27.1:
#    ------ ---------------------------------  4/26 [pysbd]
#       Successfully uninstalled protobuf-5.27.1
#    ------ ---------------------------------  4/26 [pysbd]
#    ------- --------------------------------  5/26 [protobuf]
#    ------- --------------------------------  5/26 [protobuf]
#    ------- --------------------------------  5/26 [protobuf]
#    ------- --------------------------------  5/26 [protobuf]
#    ------- --------------------------------  5/26 [protobuf]
#    ------- --------------------------------  5/26 [protobuf]
#    ------- --------------------------------  5/26 [protobuf]
#    ------- --------------------------------  5/26 [protobuf]
#    ------- --------------------------------  5/26 [protobuf]
#    --------- ------------------------------  6/26 [num2words]
#    --------- ------------------------------  6/26 [num2words]
#    --------- ------------------------------  6/26 [num2words]
#    --------- ------------------------------  6/26 [num2words]
#    --------- ------------------------------  6/26 [num2words]
#    --------- ------------------------------  6/26 [num2words]
#    --------- ------------------------------  6/26 [num2words]
#    --------- ------------------------------  6/26 [num2words]
#    --------- ------------------------------  6/26 [num2words]
#    ------------ ---------------------------  8/26 [more_itertools]
#    ------------- --------------------------  9/26 [monotonic-alignment-search]
#    --------------- ------------------------ 10/26 [markdown]
#    --------------- ------------------------ 10/26 [markdown]
#    --------------- ------------------------ 10/26 [markdown]
#    --------------- ------------------------ 10/26 [markdown]
#    --------------- ------------------------ 10/26 [markdown]
#    --------------- ------------------------ 10/26 [markdown]
#    --------------- ------------------------ 10/26 [markdown]
#    --------------- ------------------------ 10/26 [markdown]
#    ---------------- ----------------------- 11/26 [llvmlite]
#    ---------------- ----------------------- 11/26 [llvmlite]
#    ---------------- ----------------------- 11/26 [llvmlite]
#    ---------------- ----------------------- 11/26 [llvmlite]
#    ---------------- ----------------------- 11/26 [llvmlite]
#    ---------------- ----------------------- 11/26 [llvmlite]
#    ---------------- ----------------------- 11/26 [llvmlite]
#    ---------------- ----------------------- 11/26 [llvmlite]
#    ---------------- ----------------------- 11/26 [llvmlite]
#    ---------------- ----------------------- 11/26 [llvmlite]
#    ---------------- ----------------------- 11/26 [llvmlite]
#    ---------------- ----------------------- 11/26 [llvmlite]
#    ---------------- ----------------------- 11/26 [llvmlite]
#    -------------------- ------------------- 13/26 [ko-speech-tools]
#    -------------------- ------------------- 13/26 [ko-speech-tools]
#   Attempting uninstall: einops
#    -------------------- ------------------- 13/26 [ko-speech-tools]
#     Found existing installation: einops 0.4.1
#    -------------------- ------------------- 13/26 [ko-speech-tools]
#     Uninstalling einops-0.4.1:
#    -------------------- ------------------- 13/26 [ko-speech-tools]
#       Successfully uninstalled einops-0.4.1
#    -------------------- ------------------- 13/26 [ko-speech-tools]
#    --------------------- ------------------ 14/26 [einops]
#    --------------------- ------------------ 14/26 [einops]
#    --------------------- ------------------ 14/26 [einops]
#    --------------------- ------------------ 14/26 [einops]
#    --------------------- ------------------ 14/26 [einops]
#    ------------------------ --------------- 16/26 [audioread]
#    -------------------------- ------------- 17/26 [anyascii]
#    -------------------------- ------------- 17/26 [anyascii]
#    -------------------------- ------------- 17/26 [anyascii]
#    -------------------------- ------------- 17/26 [anyascii]
#    -------------------------- ------------- 17/26 [anyascii]
#    -------------------------- ------------- 17/26 [anyascii]
#    -------------------------- ------------- 17/26 [anyascii]
#    --------------------------- ------------ 18/26 [absl-py]
#    --------------------------- ------------ 18/26 [absl-py]
#    --------------------------- ------------ 18/26 [absl-py]
#    --------------------------- ------------ 18/26 [absl-py]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ----------------------------- ---------- 19/26 [tensorboard]
#    ------------------------------ --------- 20/26 [pooch]
#    ------------------------------ --------- 20/26 [pooch]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    -------------------------------- ------- 21/26 [numba]
#    --------------------------------- ------ 22/26 [inflect]
#    ----------------------------------- ---- 23/26 [librosa]
#    ----------------------------------- ---- 23/26 [librosa]
#    ----------------------------------- ---- 23/26 [librosa]
#    ----------------------------------- ---- 23/26 [librosa]
#    ----------------------------------- ---- 23/26 [librosa]
#    ------------------------------------ --- 24/26 [coqui-tts-trainer]
#    ------------------------------------ --- 24/26 [coqui-tts-trainer]
#    ------------------------------------ --- 24/26 [coqui-tts-trainer]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    -------------------------------------- - 25/26 [coqui-tts]
#    ---------------------------------------- 26/26 [coqui-tts]
#
# Successfully installed absl-py-2.5.0 anyascii-0.3.3 audioread-3.1.0 coqpit-config-0.2.5 coqui-tts-0.27.5 coqui-tts-trainer-0.3.3 docopt-0.6.2 einops-0.8.2 inflect-7.5.0 ko-speech-tools-0.1.0 lazy_loader-0.5 librosa-0.11.0 llvmlite-0.48.0 markdown-3.10.2 monotonic-alignment-search-0.2.1 more_itertools-11.1.0 msgpack-1.2.1 num2words-0.5.14 numba-0.66.0 pooch-1.9.0 protobuf-7.35.1 pysbd-0.3.4 soxr-1.1.0 tensorboard-2.21.0 tensorboard-data-server-0.7.2 typeguard-4.5.2
# WARNING: Error parsing dependencies of torchsde: .* suffix can only be used with `==` or `!=` operators
#     numpy (>=1.19.*) ; python_version >= "3.7"
#            ~~~~~~~^
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# googleapis-common-protos 1.70.0 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.35.1 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 7.35.1 which is incompatible.
# google-api-core 2.25.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5, but you have protobuf 7.35.1 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 7.35.1 which is incompatible.
# opentelemetry-proto 1.39.1 requires protobuf<7.0,>=5.0, but you have protobuf 7.35.1 which is incompatible.
# proto-plus 1.26.1 requires protobuf<7.0.0,>=3.19.0, but you have protobuf 7.35.1 which is incompatible.
# streamlit 1.55.0 requires protobuf<7,>=3.20, but you have protobuf 7.35.1 which is incompatible.
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from TTS.api import TTS
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2", gpu=True)

# generate speech by cloning a voice using default settings
tts.tts_to_file(text="Muchachos, quedense tranquilos que vamos a salir campeones.",
                file_path="NuevoSaludaMessi.wav",
                speaker_wav="SaludoMessi.wav",
                language="es")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from TTS.api import TTS
#       2 tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2", gpu=True)
#       4 # generate speech by cloning a voice using default settings
#
# File c:\Coding\Python\Lib\site-packages\TTS\api.py:14
#      12 from TTS.config import load_config
#      13 from TTS.utils.manage import ModelManager
# ---> 14 from TTS.utils.synthesizer import Synthesizer
#      16 logger = logging.getLogger(__name__)
#      19 class TTS(nn.Module):
#
# File c:\Coding\Python\Lib\site-packages\TTS\utils\synthesizer.py:13
#      10 from torch import nn
#      12 from TTS.config import load_config
# ---> 13 from TTS.tts.configs.vits_config import VitsConfig
#      14 from TTS.tts.models import setup_model as setup_tts_model
#      15 from TTS.tts.models.base_tts import BaseTTS
#
# File c:\Coding\Python\Lib\site-packages\TTS\tts\configs\vits_config.py:4
#       1 from dataclasses import dataclass, field
#       3 from TTS.tts.configs.shared_configs import BaseTTSConfig
# ----> 4 from TTS.tts.models.vits import VitsArgs, VitsAudioConfig
#       7 @dataclass
#       8 class VitsConfig(BaseTTSConfig):
#       9     """Defines parameters for VITS End2End TTS model.
#      10
#      11     Args:
#    (...)
#     105         >>> config = VitsConfig()
#     106     """
#
# File c:\Coding\Python\Lib\site-packages\TTS\tts\models\vits.py:12
#      10 import torch
#      11 import torch.distributed as dist
# ---> 12 import torchaudio
#      13 from coqpit import Coqpit
#      14 from monotonic_alignment_search import maximum_path
#
# File c:\Coding\Python\Lib\site-packages\torchaudio\__init__.py:7
#       4 import torch
#       6 # Initialize extension and backend first
# ----> 7 from . import _extension  # noqa  # usort: skip
#       8 from . import compliance, datasets, functional, models, pipelines, transforms, utils  # noqa: F401
#       9 from ._torchcodec import load_with_torchcodec, save_with_torchcodec
#
# File c:\Coding\Python\Lib\site-packages\torchaudio\_extension\__init__.py:30
#      25     _init_dll_path()
#      27 # When the extension module is built, we initialize it.
#      28 # In case of an error, we do not catch the failure as it suggests there is something
#      29 # wrong with the installation.
# ---> 30 _IS_TORCHAUDIO_EXT_AVAILABLE = _load_lib("_torchaudio")
#      31 _IS_ALIGN_AVAILABLE = False
#      32 if _IS_TORCHAUDIO_EXT_AVAILABLE:
#
# File c:\Coding\Python\Lib\site-packages\torchaudio\_extension\utils.py:56, in _load_lib(lib)
#      54 if len(paths) > 1:
#      55     warnings.warn(f"Expected a single file path to {lib}, got {paths=}")
# ---> 56 torch.ops.load_library(paths[0])
#      57 return True
#
# File c:\Coding\Python\Lib\site-packages\torch\_ops.py:1032, in _Ops.load_library(self, path)
#    1027 path = _utils_internal.resolve_library_path(path)
#    1028 with dl_open_guard():
#    1029     # Import the shared library into the process, thus running its
#    1030     # static (global) initialization code in order to register custom
#    1031     # operators with the JIT.
# -> 1032     ctypes.CDLL(path)
#    1033 self.loaded_libraries.add(path)
#
# File c:\Coding\Python\Lib\ctypes\__init__.py:376, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     373 self._FuncPtr = _FuncPtr
#     375 if handle is None:
# --> 376     self._handle = _dlopen(self._name, mode)
#     377 else:
#     378     self._handle = handle
#
# OSError: [WinError 127] The specified procedure could not be found

# %%
# !pip show torch
# !pip show torchaudio
# !pip show torchvision
# !pip list | findstr -i torch
# Out:
# Name: torch
# Version: 2.13.0
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org
# Author:
# Author-email: PyTorch Team <packages@pytorch.org>
# License-Expression: Apache-2.0 AND Apache-2.0 WITH LLVM-exception AND BSD-2-Clause AND BSD-3-Clause AND BSL-1.0 AND MIT
# Location: C:\Coding\Python\Lib\site-packages
# Requires: filelock, fsspec, jinja2, networkx, setuptools, sympy, typing-extensions
# Required-by: #N/A
# Name: torchaudio
# Version: 2.11.0
# Summary: An audio package for PyTorch
# Home-page: https://github.com/pytorch/audio
# Author: Soumith Chintala, David Pollack, Sean Naren, Peter Goldsborough, Moto Hira, Caroline Chen, Jeff Hwang, Zhaoheng Ni, Xiaohui Zhang
# Author-email: soumith@pytorch.org
# License:
# Location: C:\Coding\Python\Lib\site-packages
# Requires:
# Required-by: #N/A
# Name: torchvision
# Version: 0.28.0
# Summary: image and video datasets and models for torch deep learning
# Home-page: https://github.com/pytorch/vision
# Author: PyTorch Core Team
# Author-email: soumith@pytorch.org
# License: BSD
# Location: C:\Coding\Python\Lib\site-packages
# Requires: numpy, pillow, torch
# Required-by: #N/A
# pytorch-lightning                        1.9.4
# torch                                    2.13.0
# torchaudio                               2.11.0
# torchmetrics                             1.4.0.post0
# torchsde                                 0.2.5
# torchvision                              0.28.0
